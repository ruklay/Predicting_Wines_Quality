# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# #This is a markdown
# Content

# %%
import pandas as pd

# %%
df = pd.read_csv("Global Superstore.csv")

# %%
df.head()
# Out:
#           Category         City    Country    Customer Name Market  \
# 0  Office Supplies     Budapest    Hungary    Annie Thurman   EMEA
# 1  Office Supplies  Constantine    Algeria  Toby Braunhardt   EMEA
# 2        Furniture  Wagga Wagga  Australia      Joseph Holt   APAC
# 3  Office Supplies  Wagga Wagga  Australia      Joseph Holt   APAC
# 4  Office Supplies  Wagga Wagga  Australia      Joseph Holt   APAC
#
#   Customer ID Order Date  Year (OrderDate)       Order ID Order Priority  ...  \
# 0     AT-7352   1/1/2016              2016   HU-2011-1220           High  ...
# 1   TB-112801   1/1/2016              2016   AG-2011-2040         Medium  ...
# 2   JH-159851   1/1/2016              2016  IN-2011-47883         Medium  ...
# 3   JH-159851   1/1/2016              2016  IN-2011-47883         Medium  ...
# 4   JH-159851   1/1/2016              2016  IN-2011-47883         Medium  ...
#
#     Segment Ship Date       Ship Mode            State Sub-Category Discount  \
# ...

# %%
df.shape
# Out:
# (51290, 24)
